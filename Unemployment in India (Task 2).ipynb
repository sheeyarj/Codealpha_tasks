# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('C:\\Users\\Shreeya Rajurikar\\Downloads\\Unemployment in India.csv')
df.sample(8)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 316      Tripura   31-05-2020    Monthly                             14.71
# 557       Kerala   31-03-2020    Monthly                              9.14
# 493      Haryana   31-05-2020    Monthly                             38.46
# 588  Maharashtra   30-06-2020    Monthly                             10.01
# 734  Uttarakhand   31-01-2020    Monthly                              8.92
# 361          NaN          NaN        NaN                               NaN
# 336  Uttarakhand   30-09-2019    Monthly                              3.47
# 139    Jharkhand   30-11-2019    Monthly                              8.07
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 316             911789.0                                     46.90  Rural
# 557            4079775.0                                     33.24  Urban
# 493            2013083.0                                     38.27  Urban
# 588           16172690.0                                     37.04  Urban
# 734             725253.0                                     27.55  Urban
# 361                  NaN                                       NaN    NaN
# 336            2157845.0                                     38.79  Rural
# 139            7279628.0                                     40.26  Rural

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df[' Frequency'].value_counts()
# Out:
#  Frequency
# Monthly     381
#  Monthly    359
# Name: count, dtype: int64

# %%
print(df['Region'].value_counts())
# Out:
# Region
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 27

# %%
print('row count--->',df.shape[0])
print('column count--->',df.shape[1])
# Out:
# row count---> 768
# column count---> 7

# %%
df.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
df.dtypes.to_frame().rename(columns={0:"Data-Types"})
# Out:
#                                          Data-Types
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object

# %%
df.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing values"})
# Out:
#                                           Total No. of Missing values
# Region                                                             28
#  Date                                                              28
#  Frequency                                                         28
#  Estimated Unemployment Rate (%)                                   28
#  Estimated Employed                                                28
#  Estimated Labour Participation Rate (%)                           28
# Area                                                               28

# %%
df.rename(columns={"Region":"States"," Date":"Date"," Estimated Unemployment Rate (%)":"Estimated Unemployment Rate (%)"," Estimated Employed":"Estimated Employed"," Estimated Labour Participation Rate (%)":
                   "Estimated Labour Participation Rate (%)"},inplace=True)


df.head()
# Out:
#            States         Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                             3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                             3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                             3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                             3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)

# %%
df[:6]
# Out:
#            States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                             5.17
# 5  Andhra Pradesh 2019-10-31    Monthly                             3.52
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
# 5          12017412.0                                    43.01  Rural

# %%
df["Month"] = df["Date"].dt.month

df.head()
# Out:
#            States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  Month
# 0          11999139.0                                    43.24  Rural    5.0
# 1          11755881.0                                    42.05  Rural    6.0
# 2          12086707.0                                    43.50  Rural    7.0
# 3          12285693.0                                    43.97  Rural    8.0
# 4          12256762.0                                    44.68  Rural    9.0

# %%
df.head()
# Out:
#            States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  Month
# 0          11999139.0                                    43.24  Rural    5.0
# 1          11755881.0                                    42.05  Rural    6.0
# 2          12086707.0                                    43.50  Rural    7.0
# 3          12285693.0                                    43.97  Rural    8.0
# 4          12256762.0                                    44.68  Rural    9.0

# %%
df.drop(columns="Month",inplace=True)

# %%
df["Date"].unique()
# Out:
# <DatetimeArray>
# ['2019-05-31 00:00:00', '2019-06-30 00:00:00', '2019-07-31 00:00:00',
#  '2019-08-31 00:00:00', '2019-09-30 00:00:00', '2019-10-31 00:00:00',
#  '2019-11-30 00:00:00', '2019-12-31 00:00:00', '2020-01-31 00:00:00',
#  '2020-02-29 00:00:00', '2020-03-31 00:00:00', '2020-04-30 00:00:00',
#  '2020-05-31 00:00:00', '2020-06-30 00:00:00',                 'NaT']
# Length: 15, dtype: datetime64[ns]

# %%
df["Year"] = df["Date"].dt.year
     
df.head()
# Out:
#            States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area    Year
# 0          11999139.0                                    43.24  Rural  2019.0
# 1          11755881.0                                    42.05  Rural  2019.0
# 2          12086707.0                                    43.50  Rural  2019.0
# 3          12285693.0                                    43.97  Rural  2019.0
# 4          12256762.0                                    44.68  Rural  2019.0

# %%
df["Year"].unique()
# Out:
# array([2019., 2020.,   nan])

# %%
df["States"].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', nan, 'Chandigarh'],
#       dtype=object)

# %%
df["Area"].unique()
# Out:
# array(['Rural', nan, 'Urban'], dtype=object)

# %%
round(df.select_dtypes(include=["float","int"]).describe().T,2)
# Out:
#                                          count        mean         std  \
# Estimated Unemployment Rate (%)          740.0       11.79       10.72
# Estimated Employed                       740.0  7204460.03  8087988.43
# Estimated Labour Participation Rate (%)  740.0       42.63        8.11
# Year                                     740.0     2019.42        0.49
#
#                                               min         25%         50%  \
# Estimated Unemployment Rate (%)              0.00        4.66        8.35
# Estimated Employed                       49420.00  1190404.50  4744178.50
# Estimated Labour Participation Rate (%)     13.33       38.06       41.16
# Year                                      2019.00     2019.00     2019.00
#
#                                                  75%          max
# Estimated Unemployment Rate (%)                15.89        76.74
# Estimated Employed                       11275489.50  45777509.00
# Estimated Labour Participation Rate (%)        45.50        72.57
# Year                                         2020.00      2020.00

# %%
df[df["Estimated Unemployment Rate (%)"]>75]
# Out:
#          States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 627  Puducherry 2020-04-30    Monthly                            76.74
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# 627             68122.0                                    35.54  Urban
#
#        Year
# 627  2020.0

# %%
round(df.groupby(["States"])[["Estimated Unemployment Rate (%)","Estimated Employed",
                              "Estimated Labour Participation Rate (%)"]].mean(),2).sort_values(by="Estimated Unemployment Rate (%)",ascending=False)
# Out:
#                   Estimated Unemployment Rate (%)  Estimated Employed  \
# States
# Tripura                                     28.35           717002.64
# Haryana                                     26.28          3557072.46
# Jharkhand                                   20.58          4469240.43
# Bihar                                       18.92         12366189.14
# Himachal Pradesh                            18.54          1059823.71
# Delhi                                       16.50          2627512.86
# Jammu & Kashmir                             16.19          1799931.67
# Chandigarh                                  15.99           316831.25
# Rajasthan                                   14.06         10041064.75
# Uttar Pradesh                               12.55         28094832.18
# Punjab                                      12.03          4539362.00
# Puducherry                                  10.22           212278.08
# Kerala                                      10.12          4425899.50
# Tamil Nadu                                   9.28         12269546.75
# Goa                                          9.27           226308.33
# Chhattisgarh                                 9.24          4303498.57
# West Bengal                                  8.12         17198538.00
# Telangana                                    7.74          7939662.75
# Maharashtra                                  7.56         19990195.86
# Andhra Pradesh                               7.48          8154093.18
# Madhya Pradesh                               7.41         11115484.32
# Sikkim                                       7.25           106880.71
# Karnataka                                    6.68         10667119.29
# Gujarat                                      6.66         11402012.79
# Uttarakhand                                  6.58          1390228.11
# Assam                                        6.43          5354772.15
# Odisha                                       5.66          6545746.96
# Meghalaya                                    4.80           689736.81
#
#                   Estimated Labour Participation Rate (%)
# States
# Tripura                                             61.82
# Haryana                                             42.74
# Jharkhand                                           41.67
# Bihar                                               38.15
# Himachal Pradesh                                    44.22
# Delhi                                               38.93
# Jammu & Kashmir                                     41.03
# Chandigarh                                          39.34
# Rajasthan                                           39.97
# Uttar Pradesh                                       39.43
# Punjab                                              41.14
# Puducherry                                          38.99
# Kerala                                              34.87
# Tamil Nadu                                          40.87
# Goa                                                 39.25
# Chhattisgarh                                        42.81
# West Bengal                                         45.42
# Telangana                                           53.00
# Maharashtra                                         42.30
# Andhra Pradesh                                      39.38
# Madhya Pradesh                                      38.82
# Sikkim                                              46.07
# Karnataka                                           41.35
# Gujarat                                             46.10
# Uttarakhand                                         33.78
# Assam                                               44.87
# Odisha                                              38.93
# Meghalaya                                           57.08

# %%
# !pip install seaborn --upgrade
import seaborn as sns
import matplotlib.pyplot as plt
x = df.groupby(["States"])["Estimated Unemployment Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,5))

# Pass x and y as columns within the data argument
sns.barplot(data=x, x=x.index, y="Estimated Unemployment Rate (%)", palette=sns.color_palette("Blues",28)[::-1])

plt.title("State wise Average Unemployment Rate",fontweight="black",fontsize=20,pad=10)
plt.xticks(rotation=90)
plt.show()
# Out:
# Requirement already satisfied: seaborn in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# !pip install seaborn --upgrade
import seaborn as sns
import matplotlib.pyplot as plt
x = df.groupby(["States"])["Estimated Labour Participation Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,5))

# Pass x and y as columns within the data argument
sns.barplot(data=x, x=x.index, y="Estimated Labour Participation Rate (%)", palette=sns.color_palette("Blues",28)[::-1])

plt.title("State wise Average Labour Participation Rate",fontweight="black",fontsize=20,pad=10)
plt.xticks(rotation=90)
plt.show()
# Out:
# Requirement already satisfied: seaborn in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# !pip install seaborn --upgrade
import seaborn as sns
import matplotlib.pyplot as plt

x = df.groupby(["Area"])["Estimated Unemployment Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)

# Pass x and y as columns within the data argument
sns.barplot(data=x, x=x.index, y="Estimated Unemployment Rate (%)", palette=sns.color_palette("Blues",3)[::-1])

plt.title("State wise Average Unemployment Rate",fontweight="black",fontsize=15,pad=10)
plt.xticks(rotation=90)

z = df.groupby(["Area"])["Estimated Labour Participation Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.subplot(1,2,2)

# Pass x and y as columns within the data argument
sns.barplot(data=z, x=z.index, y="Estimated Labour Participation Rate (%)", palette=sns.color_palette("Blues",3)[::-1])

plt.title("State wise Average Labour Participation Rate",fontweight="black",fontsize=15,pad=10)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: seaborn in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shreeya rajurikar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
# Pass x and y as keyword arguments
ax = sns.lineplot(x=df["Year"], y=df["Estimated Unemployment Rate (%)"], color="Blue")
ax.set_xticklabels(["","2019","","","","","2020"])
plt.title("Unemployment Rate Over the Years",fontweight="black",fontsize=20,pad=10)

plt.subplot(1,2,2)
# Pass x and y as keyword arguments
ax = sns.lineplot(x=df["Year"], y=df["Estimated Labour Participation Rate (%)"],color="Red")
ax.set_xticklabels(["","2019","","","","","2020"])
plt.title("Labour Rate Over the Years",fontweight="black",fontsize=20,pad=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Shreeya Rajurikar\AppData\Local\Temp\ipykernel_2420\1926987149.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["","2019","","","","","2020"])
# C:\Users\Shreeya Rajurikar\AppData\Local\Temp\ipykernel_2420\1926987149.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["","2019","","","","","2020"])

# %%
import matplotlib.pyplot as plt
     
df.columns
# Out:
# Index(['States', 'Date', ' Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area',
#        'Year'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))

# Pass x and y as columns within the data argument
# Use DataFrame x instead of z
sns.barplot(data=x, x="Estimated Unemployment Rate (%)", y=x.index, palette=sns.color_palette("Blues",30)[::-1])

plt.title("Most Affected States/UT of India During the COVID-19 Lockdown in terms of Unemployment Rate",
          fontweight="black",fontsize=20,pad=20)
plt.show()

# %%
plt.figure(figsize=(10,5))
# Pass x and y as keyword arguments
sns.barplot(x=z["Estimated Labour Participation Rate (%)"],y=z.index,palette=sns.color_palette("Blues",30)[::-1])
plt.title("Most Affected States/UT of India During the COVID-19 Lockdown in terms of Labour Rate",
          fontweight="black",fontsize=20,pad=30)
plt.show()
